# %%
import pandas as pd

# %%
path = "./data/moses/test.txt"

pd.read_csv(path,squeeze=True).astype(str).tolist()
# Out:
# ['COc1ccc(-c2cc(=O)c3c(O)c(OC)c(OC)cc3o2)cc1O',
#  'CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(F)ccc1-2',
#  'Clc1ccccc1-c1nc(-c2ccncc2)no1',
#  'CC(C)(Oc1ccc(Cl)cc1)C(=O)OCc1cccc(CO)n1',
#  'Cc1nc2c(OCc3ccccc3)cccn2c1CC#N',
#  'O=C1c2cccnc2CN1Cc1ccccc1Cl',
#  'O=C(NC1CCc2ccccc2C1)c1ccncc1',
#  'OC(Cn1cncn1)(Cn1cncn1)c1ccc(F)cc1F',
#  'Cc1[nH]cnc1Cc1nc(-c2ccccc2)cs1',
#  'COc1ccc(-c2nc3n(c2-c2ccncc2)CCC3)cc1',
#  'CC(=O)NC(C(=O)NCc1ccccc1)c1ccco1',
#  'COc1ccc(C2CNC(=O)C2)cc1OC1CCCC1',
#  'CCCn1c(=O)c2[nH]c(C3CCC(=O)C3)nc2n(CCC)c1=O',
#  'C=C1C(CO)C(O)CC1n1cnc2c(=O)[nH]c(N)nc21',
#  'COc1cc(CNc2ccc(C)cc2)cc(OC)c1OC',
#  'O=C(NCCc1cccc2ccccc12)C1CCC1',
#  'O=C1c2ccccc2-c2c3c(cc4ccnc1c24)OCO3',
#  'O=C(CN1C(=O)c2ccccc2S1(=O)=O)Nc1ccc(O)cc1',
#  'Cc1ccc(Sc2cncc3sc(C(N)=O)cc23)cc1',
#  'Cc1ccc2nc(N)[nH]c(=O)c2c1Sc1ccncc1',
#  'COc1cc2ncc(NC3CCC(O)CC3)nc2cc1OC',
#  'Nc1cnc(-c2cc(Cl)cc(Cl)c2Cl)c(N)n1',
#  'CCN1c2ncccc2NC(=O)c2cc(Br)cnc21',
#  'CC(C(=O)NC1CC1)S(=O)(=O)c1ccccc1Br',
# ...

# %%
def a():
    print("aaaa")
def b():
    print("bbbb")
    
def c(x,y):
    return x+y

def d(q,w,e,m,n):
    q()
    z=w(m,n)
    e()
    return z

# %%
p=d(a,c,b,1,2)
print(p)
# Out:
# aaaa
# bbbb
# 3
